# %% [markdown]
# # Advanced Collaborative Filtering

# %% [markdown]
# Note: this lab has been tested with Python 3.10. We recommend using the same Python version if there are problems with libraries used in this lab.

# %%
# Load data generated in W6 Lab or the provided data splits (see Absalon, W7 Lab)
import pandas as pd

df_train = pd.read_pickle("train_dataframe.pkl")
df_test = pd.read_pickle("test_dataframe.pkl")

# %% [markdown]
# ## Exercise 1
#
# For this exercise, you can use the Python library Scikit-Surprise. Please find the documentation here: https://surprise.readthedocs.io/en/stable/getting_started.html.
#
# Define an SVD model with user and item biases that uses Stochastic Gradient Descend (SGD) to estimate the low-rank matrix based on only observed ratings.
#
# Fit the model on the full training set with $30$ latent factors and $100$ epochs. Keep Scikit-Surprise's default setting for all other parameters, but set the random state to $0$ for comparable results.
#
# Use the model to predict the unobserved ratings for the users in the training set. How many predictions are there and what is the average of all the predictions? Round the average of all predictions to the third decimal point.

# %%
import random
import numpy as np
from surprise import Reader, Dataset, SVD

# %%
# Convert train data format
reader = Reader(rating_scale=(1, 5))
training_matrix = Dataset.load_from_df(df_train[['reviewerID', 'asin', 'overall']], reader)

my_seed = 0
random.seed(my_seed)
np.random.seed(my_seed)

trainset = training_matrix.build_full_trainset()

alg = SVD(n_factors=30, n_epochs=100, random_state=my_seed)
alg.fit(trainset)

testset = trainset.build_anti_testset()

# # Detect users from training set that are not in test and filter them out
# all_train_users_id = df_train[df_train.reviewerID.isin(df_train.reviewerID.unique().tolist())].reviewerID.unique()
# all_train_items_id = df_train.asin.unique()

# training_user_item_combinations = set(zip(df_train.reviewerID, df_train.asin))


#unobserved_ratings = [(reviewerID,asin,0) for reviewerID in all_train_users_id for asin in all_train_items_id if (reviewerID, asin) not in training_user_item_combinations]

# For some reason we need to predict user-item entries for users we don't have any info in the train set - Cold start problem, hello?
predictions = alg.test(testset)

#Write your code here

# %%
len(predictions)
# Out:
# 54746

# %%
value_predictions = [pred.est for pred in predictions]
sum(value_predictions)/len(value_predictions)
# Out:
# 4.413418116878057

# %% [markdown]
# ## Exercise 2
#
# We will implement the Neural Matrix Factorization model using the Python library RecBole.
# Please find the documentation here: https://recbole.io/docs/

# %%
#Uncomment and run the following line if you need to install RecBole
#!pip install recbole

# %%
#Uncomment and run the following line if you need to install ray. This is needed when calling run_recbole
#!pip install ray

# %%
import os
import pandas as pd
from recbole.quick_start import run_recbole

# %% [markdown]
# ### Exercise 2.1
#
# Convert the dataset to the format which can be read by RecBole.
#
# More information regarding the input data format can be found here:
# https://recbole.io/docs/user_guide/usage/running_new_dataset.html

# %%
df_train.columns
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin', 'style',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'image'],
#       dtype='object')

# %%
#We are creating a dictionary that maps the column names in our dataset to the column names required by RecBole

#Fill this dictionary with keys that are column names in our dataset that correspond to user_id, item_id, rating, and timestamp
#Fill the values of the dictionary according to the given documentation
col_name_dict = {
    "reviewerID": "user_id:token",
    "asin": "item_id:token",
    "overall": "rating:float",
    "unixReviewTime": "timestamp:float"
                }

# %%
#this method converts a dataframe to a .inter file, and saves it in the folder "data" under the name 'file_name'
def convert_df_to_inter(df:pd.DataFrame, col_name_dict:dict, file_name:str):
    inter = df.copy()
    selected_cols = col_name_dict.keys()
    inter = inter[selected_cols]
    #write your code to rename the columns in inter using col_name_dict
    inter = inter.rename(columns=col_name_dict)

    if not os.path.exists("data"):
        os.makedirs("data")
    inter.to_csv("data/"+file_name, index=False, sep="\t")

# %%
list(col_name_dict.keys())
# Out:
# ['reviewerID', 'asin', 'overall', 'unixReviewTime']

# %%
#create an extra, empty dataframe with the same column names in the keys of col_name_dict
#we will use this as a dummy validation file
df_extra = pd.DataFrame(columns=col_name_dict.keys())

# %%
convert_df_to_inter(df_train, col_name_dict, "data.train.inter")
convert_df_to_inter(df_test, col_name_dict, "data.test.inter")
convert_df_to_inter(df_extra, col_name_dict, "data.extra.inter")

# %% [markdown]
# ### Exercise 2.2
# Train the Neural Matrix Factorization model on the whole training dataset for $100$ epochs.
#
# Evaluate the model on the test set, based on HR, MRR, Precision, MAP, and Recall at $k \in \{5, 10, 20\}$ respectively and round the scores up to 3 decimal places (It is fine if you have different results in the third decimal point).
# Keep the rest of the default settings of RecBole the same.
#
# Note: RecBole's MAP normalises the recall base by $\min\{k,G\}$, where $G$ is the recall base (see W7 lecture and homework solution)

# %% [markdown]
# Note: A non exhaustive list of properties that can be set using the config_dict parameter of the run_recbole() method can be found here:
# https://github.com/RUCAIBox/RecBole/blob/master/recbole/properties/overall.yaml

# %%
result = run_recbole(
                    model="NeuMF",
                    dataset="data",
                    config_dict={
                        "data_path":"./",
                        "benchmark_filename": ['train', 'extra', 'test'],
                        "epochs": 100,
                        "seed": 2020,
                        "show_progress": True,
                        "metrics": ["Hit","MRR","MAP","Precision", "Recall"],
                        "topk": [5, 10, 20],
                        "metric_decimal_place": 3,
                        "eval_args": {"split":  {"KFold": 5}}
                    })
# Out:
# 02 Mar 02:16    INFO  ['/opt/anaconda3/envs/recsys/lib/python3.10/site-packages/ipykernel_launcher.py', '--f=/Users/danielpenchev/Library/Jupyter/runtime/kernel-v39e31d61ae42945e50d964dd5c12404156b034fff.json']
# 02 Mar 02:16    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = ./data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'KFold': 5}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Hit', 'MRR', 'MAP', 'Precision', 'Recall']
# topk = [5, 10, 20]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 3
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'extra', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mf_embedding_size = 64
# mlp_embedding_size = 64
# mlp_hidden_size = [128, 64]
# dropout_prob = 0.1
# mf_train = True
# mlp_train = True
# use_pretrain = False
# mf_pretrain_path = None
# mlp_pretrain_path = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /opt/anaconda3/envs/recsys/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# 02 Mar 02:16    INFO  data
# The number of users: 982
# Average actions of users: 4.161060142711519
# The number of items: 85
# Average actions of items: 48.595238095238095
# The number of inters: 4082
# The sparsity of the dataset: 95.10962022283455%
# Remain Fields: ['user_id', 'item_id']
# 02 Mar 02:16    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 02 Mar 02:16    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'KFold': 5}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 02 Mar 02:16    INFO  NeuMF(
#   (user_mf_embedding): Embedding(982, 64)
#   (item_mf_embedding): Embedding(85, 64)
#   (user_mlp_embedding): Embedding(982, 64)
#   (item_mlp_embedding): Embedding(85, 64)
#   (mlp_layers): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=128, out_features=128, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=128, out_features=64, bias=True)
#       (5): ReLU()
#     )
#   )
#   (predict_layer): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 161473
# 02 Mar 02:16    INFO  FLOPs: 24960.0
# Train     0:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 93.20it/s]
# 02 Mar 02:16    INFO  epoch 0 training [time: 0.05s, train loss: 2.7714]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     1:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 101.60it/s]
# 02 Mar 02:16    INFO  epoch 1 training [time: 0.05s, train loss: 2.7665]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     2:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 113.81it/s]
# 02 Mar 02:16    INFO  epoch 2 training [time: 0.04s, train loss: 2.7550]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     3:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 148.37it/s]
# 02 Mar 02:16    INFO  epoch 3 training [time: 0.03s, train loss: 2.7259]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     4:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 94.22it/s]
# 02 Mar 02:16    INFO  epoch 4 training [time: 0.06s, train loss: 2.6791]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     5:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 139.27it/s]
# 02 Mar 02:16    INFO  epoch 5 training [time: 0.04s, train loss: 2.6079]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     6:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 146.87it/s]
# 02 Mar 02:16    INFO  epoch 6 training [time: 0.03s, train loss: 2.5014]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     7:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 147.82it/s]
# 02 Mar 02:16    INFO  epoch 7 training [time: 0.03s, train loss: 2.3835]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     8:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 148.60it/s]
# 02 Mar 02:16    INFO  epoch 8 training [time: 0.03s, train loss: 2.2069]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train     9:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 98.97it/s]
# 02 Mar 02:16    INFO  epoch 9 training [time: 0.05s, train loss: 2.0033]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    10:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 152.65it/s]
# 02 Mar 02:16    INFO  epoch 10 training [time: 0.03s, train loss: 1.7077]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    11:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 144.03it/s]
# 02 Mar 02:16    INFO  epoch 11 training [time: 0.03s, train loss: 1.4823]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    12:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 145.60it/s]
# 02 Mar 02:16    INFO  epoch 12 training [time: 0.03s, train loss: 1.1231]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    13:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 151.83it/s]
# 02 Mar 02:16    INFO  epoch 13 training [time: 0.03s, train loss: 0.9101]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    14:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 151.14it/s]
# 02 Mar 02:16    INFO  epoch 14 training [time: 0.03s, train loss: 0.7599]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    15:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 151.00it/s]
# 02 Mar 02:16    INFO  epoch 15 training [time: 0.03s, train loss: 0.7086]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    16:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 146.79it/s]
# 02 Mar 02:16    INFO  epoch 16 training [time: 0.03s, train loss: 0.6301]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    17:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 138.57it/s]
# 02 Mar 02:16    INFO  epoch 17 training [time: 0.04s, train loss: 0.6109]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    18:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 107.03it/s]
# 02 Mar 02:16    INFO  epoch 18 training [time: 0.05s, train loss: 0.5601]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train    19:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 145.60it/s]
# 02 Mar 02:16    INFO  epoch 19 training [time: 0.03s, train loss: 0.6461]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# Train
   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 140.24it/s]
# 02 Mar 02:16    INFO  epoch 99 training [time: 0.04s, train loss: 0.1809]
# 02 Mar 02:16    INFO  Saving current: saved/NeuMF-Mar-02-2025_02-16-38.pth
# 02 Mar 02:16    INFO  Loading model structure and parameters from saved/NeuMF-Mar-02-2025_02-16-38.pth
# Evaluate   :   0%|                                                           | 0/20 [00:00<?, ?it/s]: 100%|█████████████████████████████████████████████████| 20/20 [00:00<00:00, 300.14it/s]
# 02 Mar 02:16    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     7.00 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.43 G/24.00 G |
# +-------------+----------------+
# 02 Mar 02:16    INFO  best valid : None
# 02 Mar 02:16    INFO  test result: OrderedDict([('hit@5', 0.809), ('hit@10', 0.819), ('hit@20', 0.857), ('mrr@5', 0.529), ('mrr@10', 0.53), ('mrr@20', 0.533), ('map@5', 0.529), ('map@10', 0.53), ('map@20', 0.533), ('precision@5', 0.162), ('precision@10', 0.082), ('precision@20', 0.043), ('recall@5', 0.809), ('recall@10', 0.819), ('recall@20', 0.857)])

# %%
result = run_recbole(
                    model="NeuMF",
                    dataset="data",
                    config_dict={
                        "data_path":"./",
                        "benchmark_filename": ['train', 'extra', 'test'],
                        "epochs": 100,
                        "seed": 2020,
                        "show_progress": True,
                        "metrics": ["Hit","MRR","MAP","Precision", "Recall"],
                        "topk": [5, 10, 20],
                        "metric_decimal_place": 3
                    })
# Out:
# 01 Mar 01:44    INFO  ['/opt/anaconda3/envs/recsys/lib/python3.10/site-packages/ipykernel_launcher.py', '--f=/Users/danielpenchev/Library/Jupyter/runtime/kernel-v39e31d61ae42945e50d964dd5c12404156b034fff.json']
# 01 Mar 01:44    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = ./data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = False
# metrics = ['Hit', 'MRR', 'MAP', 'Precision', 'Recall']
# topk = [5, 10, 20]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 3
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'extra', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mf_embedding_size = 64
# mlp_embedding_size = 64
# mlp_hidden_size = [128, 64]
# dropout_prob = 0.1
# mf_train = True
# mlp_train = True
# use_pretrain = False
# mf_pretrain_path = None
# mlp_pretrain_path = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /opt/anaconda3/envs/recsys/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# 01 Mar 01:44    INFO  data
# The number of users: 982
# Average actions of users: 4.161060142711519
# The number of items: 85
# Average actions of items: 48.595238095238095
# The number of inters: 4082
# The sparsity of the dataset: 95.10962022283455%
# Remain Fields: ['user_id', 'item_id']
# 01 Mar 01:44    INFO  [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 01 Mar 01:44    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 01 Mar 01:44    INFO  NeuMF(
#   (user_mf_embedding): Embedding(982, 64)
#   (item_mf_embedding): Embedding(85, 64)
#   (user_mlp_embedding): Embedding(982, 64)
#   (item_mlp_embedding): Embedding(85, 64)
#   (mlp_layers): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=128, out_features=128, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=128, out_features=64, bias=True)
#       (5): ReLU()
#     )
#   )
#   (predict_layer): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 161473
# 01 Mar 01:44    INFO  FLOPs: 24960.0
# Train     0:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 63.16it/s]
# 01 Mar 01:44    INFO  epoch 0 training [time: 0.09s, train loss: 2.7714]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     1:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 91.63it/s]
# 01 Mar 01:44    INFO  epoch 1 training [time: 0.05s, train loss: 2.7665]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     2:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 137.03it/s]
# 01 Mar 01:44    INFO  epoch 2 training [time: 0.03s, train loss: 2.7550]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     3:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 139.89it/s]
# 01 Mar 01:44    INFO  epoch 3 training [time: 0.03s, train loss: 2.7259]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     4:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 141.36it/s]
# 01 Mar 01:44    INFO  epoch 4 training [time: 0.03s, train loss: 2.6791]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     5:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 141.78it/s]
# 01 Mar 01:44    INFO  epoch 5 training [time: 0.03s, train loss: 2.6079]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     6:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 90.66it/s]
# 01 Mar 01:44    INFO  epoch 6 training [time: 0.05s, train loss: 2.5014]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     7:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 146.34it/s]
# 01 Mar 01:44    INFO  epoch 7 training [time: 0.03s, train loss: 2.3835]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     8:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 138.67it/s]
# 01 Mar 01:44    INFO  epoch 8 training [time: 0.03s, train loss: 2.2069]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train     9:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 135.58it/s]
# 01 Mar 01:44    INFO  epoch 9 training [time: 0.03s, train loss: 2.0033]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    10:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 137.51it/s]
# 01 Mar 01:44    INFO  epoch 10 training [time: 0.03s, train loss: 1.7077]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    11:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 115.96it/s]
# 01 Mar 01:44    INFO  epoch 11 training [time: 0.04s, train loss: 1.4823]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    12:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 136.13it/s]
# 01 Mar 01:44    INFO  epoch 12 training [time: 0.03s, train loss: 1.1231]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    13:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 140.63it/s]
# 01 Mar 01:44    INFO  epoch 13 training [time: 0.03s, train loss: 0.9101]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    14:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 142.33it/s]
# 01 Mar 01:44    INFO  epoch 14 training [time: 0.03s, train loss: 0.7599]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    15:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|████████████████████████████████████████████████████| 4/4 [00:00<00:00, 97.44it/s]
# 01 Mar 01:44    INFO  epoch 15 training [time: 0.04s, train loss: 0.7086]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train
   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 144.48it/s]
# 01 Mar 01:44    INFO  epoch 96 training [time: 0.03s, train loss: 0.1824]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    97:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 134.14it/s]
# 01 Mar 01:44    INFO  epoch 97 training [time: 0.03s, train loss: 0.1816]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    98:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 147.81it/s]
# 01 Mar 01:44    INFO  epoch 98 training [time: 0.03s, train loss: 0.1902]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# Train    99:   0%|                                                            | 0/4 [00:00<?, ?it/s]: 100%|███████████████████████████████████████████████████| 4/4 [00:00<00:00, 140.94it/s]
# 01 Mar 01:44    INFO  epoch 99 training [time: 0.03s, train loss: 0.1809]
# 01 Mar 01:44    INFO  Saving current: saved/NeuMF-Mar-01-2025_01-44-20.pth
# 01 Mar 01:44    INFO  Loading model structure and parameters from saved/NeuMF-Mar-01-2025_01-44-20.pth
# Evaluate   :   0%|                                                           | 0/20 [00:00<?, ?it/s]: 100%|█████████████████████████████████████████████████| 20/20 [00:00<00:00, 331.27it/s]
# 01 Mar 01:44    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     5.80 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.40 G/24.00 G |
# +-------------+----------------+
# 01 Mar 01:44    INFO  best valid : None
# 01 Mar 01:44    INFO  test result: OrderedDict([('hit@5', 0.809), ('hit@10', 0.819), ('hit@20', 0.857), ('mrr@5', 0.529), ('mrr@10', 0.53), ('mrr@20', 0.533), ('map@5', 0.529), ('map@10', 0.53), ('map@20', 0.533), ('precision@5', 0.162), ('precision@10', 0.082), ('precision@20', 0.043), ('recall@5', 0.809), ('recall@10', 0.819), ('recall@20', 0.857)])

# %%
result
# Out:
# {'best_valid_score': -inf,
#  'valid_score_bigger': True,
#  'best_valid_result': None,
#  'test_result': OrderedDict([('hit@5', 0.808),
#               ('hit@10', 0.819),
#               ('hit@20', 0.857),
#               ('mrr@5', 0.529),
#               ('mrr@10', 0.53),
#               ('mrr@20', 0.533),
#               ('map@5', 0.529),
#               ('map@10', 0.53),
#               ('map@20', 0.533),
#               ('precision@5', 0.162),
#               ('precision@10', 0.082),
#               ('precision@20', 0.043),
#               ('recall@5', 0.808),
#               ('recall@10', 0.819),
#               ('recall@20', 0.857)])}

# %% [markdown]
# ## Exercise 3
#
# Let's create a graph-based recommender system, defining neighbourhoods with random walks. Build a bipartite graph (i.e., edges only between users and items) where nodes are users and items; a **bidirectional** edge $(u,i)$ exists in the graph if user $u$ has rated item $i$ with a score $>3$.
#
# Implement the Page Rank algorithm to find the top-10 recommended items for user `ARARUVZ8RUF5T`. You can use the `pagerank` method from the library `networkx`. Assume a damping factor of $0.85$ and leave the rest of parameters by default.

# %%
# !pip install networkx

# %%
import numpy as np
import networkx as nx
from operator import itemgetter

# Prepare the data
def convert_data(df):
    df_convert = df[df.overall > 3] #get the rows in the df where the rating is >3
    df_convert = df_convert[["asin","reviewerID"]]
    df_convert_arr = df_convert.values
    return df_convert_arr

train_df = convert_data(df_train)

# %%
''' Hyper Parameters '''
def parameter_dict_from_vector(vector):
    return {
        "W_USER_ITEM" : vector[0],
        "W_USER_ITEM_BACK" : vector[1]
        }

''' Building Graph '''
class InteractionGraph:
    def __init__(self):
        self.graph = nx.MultiDiGraph()
        
    def add_nodes_from_edge_array(self, edge_array, type_1, type_2):
        nodes = [(x[0], {'type': type_1}) for x in edge_array] \
        + [(x[1], {'type': type_2}) for x in edge_array]
        self.graph.add_nodes_from(nodes)

    def add_edges_from_array(self, array, weight_front=1.0, weight_back=1.0):
        forward_edges = [(x[0], x[1], weight_front) for x in array]
        back_edges = [(x[1], x[0], weight_back) for x in array]
        self.graph.add_weighted_edges_from(forward_edges)
        self.graph.add_weighted_edges_from(back_edges)

def build_graph(parameter_dictionary, user_item_array):
    multigraph = InteractionGraph()
    multigraph.add_nodes_from_edge_array(user_item_array, 'item', 'user')
    multigraph.add_edges_from_array(user_item_array, 
                                    parameter_dictionary["W_USER_ITEM"], 
                                    parameter_dictionary["W_USER_ITEM_BACK"])
    return multigraph

class RecommendationEngine:
    def __init__(self, multigraph, damping_factor = 0.3):
        self.graph = nx.DiGraph()
        
        # if we have multple edges with the same source and destination, then create a single edge with the cummulative sum of those edges' weight
        for u,v,d in multigraph.graph.edges(data=True):
            w = d['weight']
            if self.graph.has_edge(u,v):
                self.graph[u][v]['weight'] += w
            else:
                self.graph.add_edge(u,v,weight=w)
        self.nodes = list(self.graph.nodes)
        self.damping_factor = damping_factor
        
        #this part keeps track of items that have been rated by each user in the training set
        self.user_item_dict = {}
        for n in multigraph.graph.nodes.data():
            if n[1]['type'] == 'user':
                self.user_item_dict[n[0]] = set()
        for e in multigraph.graph.edges:
            if e[0] in self.user_item_dict:
                self.user_item_dict[e[0]].add(e[1])

    def generate_pr(self, damping_factor):
        pr = nx.pagerank(self.graph, damping_factor)
        pr_sorted = dict(
            #sort pr by descending probability values
            sorted(pr.items(), key=lambda x: x[1], reverse=True)
            )
        pr_list = [(k, v) for k, v in pr_sorted.items()]
        return pr_list
    
    def generate_recommendations(self, user):
        pr_list = self.generate_pr(self.damping_factor)
        print(self.graph.nodes)
        result = [item for (item, _) in pr_list if item not in self.user_item_dict[user] and item not in self.user_item_dict.keys()]        
        #Given the user, remove items in their recommendation list that they have rated in the training set
        #hint: you can use user_item_dict for this
        return result

# %% [markdown]
# ('B000URXP6E', 0.12199812480203007),
# ('B0012Y0ZG2', 0.0734194898666046),
# ('B00006L9LC', 0.06842860929512946),

# %%
train_df
# Out:
# array([['B0009RF9DW', 'A105A034ZG9EHO'],
#        ['B000FI4S1E', 'A105A034ZG9EHO'],
#        ['B000URXP6E', 'A105A034ZG9EHO'],
#        ...,
#        ['B0009RF9DW', 'AZRD4IZU6TBFV'],
#        ['B000FI4S1E', 'AZRD4IZU6TBFV'],
#        ['B000URXP6E', 'AZRD4IZU6TBFV']], dtype=object)

# %%
df_train[df_train.reviewerID=="A281NPSIMI1C2R"]
# Out:
#      overall  verified   reviewTime      reviewerID        asin  \
# 487      5.0     False  06 28, 2005  A281NPSIMI1C2R  B0002JHI1I
# 489      5.0     False  09 22, 2017  A281NPSIMI1C2R  B0006O10P4
#
#                                                  style       reviewerName  \
# 487                                                NaN  Rebecca of Amazon
# 489  {'Size:': ' 3 oz.', 'Scent Name:': ' Frankince...  Rebecca of Amazon
#
#                                             reviewText  \
# 487  CoQ10 is essential for healthy youthful skin. ...
# 489  Warm, soothing and a little spicy. This zum ba...
#
#                          summary  unixReviewTime vote image
# 487  Heavenly Lavender Fragrance      1119916800    6   NaN
# 489           Soothing and Spicy      1506038400  NaN   NaN

# %%
train_df
# Out:
# array([['B0009RF9DW', 'A105A034ZG9EHO'],
#        ['B000FI4S1E', 'A105A034ZG9EHO'],
#        ['B000URXP6E', 'A105A034ZG9EHO'],
#        ...,
#        ['B0009RF9DW', 'AZRD4IZU6TBFV'],
#        ['B000FI4S1E', 'AZRD4IZU6TBFV'],
#        ['B000URXP6E', 'AZRD4IZU6TBFV']], dtype=object)

# %%
damping_factor = 0.85 #fill this

# Build the graph
graph = build_graph(parameter_dict_from_vector(np.ones(2)), train_df)
# Build the recommender system with page rank
recommender = RecommendationEngine(graph, damping_factor)

#print(recommender.graph.nodes)

# Get top-K recommendations for the given user 
user_id = "ARARUVZ8RUF5T"
K = 10

recommender.generate_recommendations(user_id)[:K]
# Out:
# ['B0009RF9DW', 'A105A034ZG9EHO', 'A10JB7YPWZGRF4', 'A10P0NAKKRYKTZ', 'A115LE3GBAO8I6', 'A121C9UWQFW5W6', 'A12HWYJ6G58FGV', 'A12X146LZM6KM0', 'A12X3J7IITW1J6', 'A13B2J5IBGS8Y2', 'A149WHPACMTSLO', 'A14BV6AW987ZDN', 'A14SJT4M0BP298', 'A14Y0FPHPBKBAF', 'A14YENXHLKG9WL', 'A150XCEZV6KF5G', 'A156IOMOA59X7N', 'A1577W1CXJ2WI9', 'A157AUOFPJQ46Q', 'A15IDG691XH2XI', 'A15TMUEDCVMOBF', 'A177B2VPWX4P55', 'A17ZAS11CK1HG8', 'A18KOO6VMJJ70S', 'A190ENIBZ72LMF', 'A19Q4TR24DNXB5', 'A1A6EANMBA02NW', 'A1A7LP8GUKEPZM', 'A1AFK6DIZFYQ2V', 'A1AFSSJ58HYER7', 'A1AIIT0GCPBL2M', 'A1AKH1GJBE5CX5', 'A1AWB5QE4T9LPM', 'A1B1HM7OZLXFO2', 'A1B5D7AI4KYG98', 'A1CF9LS3PV9ZOR', 'A1CJRTU646COUL', 'A1CURM7FGX5UJP', 'A1D3G0HL756T8B', 'A1DFZPQPCHBYTY', 'A1EPD7UQU3MXBT', 'A1F1B2NU2TQAJV', 'A1FEQTQIVZKAY', 'A1GO71H0UB95WN', 'A1GVT488CKU6ZB', 'A1GVTXX0S7ANZ8', 'A1HPJKECRYBG6V', 'A1IT5WIUU0FKAV', 'A1IW22SHM
TE8', 'A2C114BZC4OO6A', 'A2C8L2HEMJ4VT7', 'A2CPG6CY3NAYMU', 'A2D0I7M2G43WWP', 'A2D48QTM7CXR0D', 'A2E3YYK70W49NO', 'A2EBR70V6P9W0N', 'A2EHOO31B1KDP4', 'A2F218M5AOPU6T', 'A2F9G1A29XS38E', 'A2G7EEQJKKOU8R', 'A2H1NTYWYYA0XM', 'A2H85FZ61BSTLA', 'A2H99IQJ0JT4MU', 'A2H9JIWY7JDD3J', 'A2HT5WENL8E5S6', 'A2HYL1CITWDZJK', 'A2I02X97TQCOHX', 'A2IJOEZZTLRJ83', 'A2INILPDI33JG3', 'A2IXGQP8IXSJXW', 'A2IYMZSE5YVU7F', 'A2J50ZCVKL1H9L', 'A2J5HTXL1X2FN3', 'A2JAEYUNQB6BIF', 'A2K4C2K7NZLOQI', 'A2KA5PR2AKM7ZU', 'A2KUYYA021Y4KO', 'A2KZH1QYHRJRB7', 'A2L6FOYXXFC3TX', 'A2L7E955AXRHRA', 'A2LFGBMPZPSAMV', 'A2LK2NPDGPG9BS', 'A2LY3LPGRERLPW', 'A2M0OIN5678XKQ', 'A2NAS3M5B7Z8Q3', 'A2NH58DY5F0XSZ', 'A2NXR4T75E4QM7', 'A2O4T6MQ540AGF', 'A2OMMYTOUX444Q', 'A2POJYG128B2EX', 'A2PPWA67FGO7BF', 'A2PW5N4QDA3AG9', 'A2Q7PO5LDVGUOW', 'A2QLQVPUZG2JXU', 'A2R03U5UAX219B', 'A2RFDGEW20UK6W', 'A2RH42TOQUF3LQ', 'A2RID8C0PQDMAS', 'A2S1BDB8QFVSQ2', 'A2TCHF5VRXR7YF', 'A2TEMMADR9GNRO', 'A2TY2IK21P4498', 'A2TYF9WCP31IGZ', 'A2TZFRXV3E4D7O', 'A2TZW7B0YG2ZJQ', 'A2UH411RVKUH96', 'A2VABJ7S3OTH4K', 'A2W643VRI6ELN', 'A2X5PW8CYW4U1D', 'A2XDLY3PL0CGBD', 'A2XNLIC0O07GPW', 'A2XPTXCAX8WLHU', 'A2Z54QPJOS4TQA', 'A300SV028Q2Z4C', 'A324WQKVD3TLLQ', 'A32BY7UM2ZCWHM', 'A32MXI9376X72P', 'A32NCLA7SHQBFW', 'A32PX7W05VFWOJ', 'A32RAW9ILQYP9S', 'A32SDP7KQV0N44', 'A337VOJXCV97F6', 'A34GB2ZA1JLGND', 'A34KXLHGO3SWB7', 'A35QTJ23YREVYX', 'A36JEYR65W1LTO', 'A36LNAKD2FOHVX', 'A37DCOJBXHTODF', 'A37PANLDA6ENJK', 'A37TA115S10 ...
# ['B000URXP6E',
#  'B0012Y0ZG2',
#  'B00006L9LC',
#  'B0009RF9DW',
#  'B000FI4S1E',
#  'B001OHV1H4',
#  'B00W259T7G',
#  'B0010ZBORW',
#  'B0013NB7DW',
#  'B019FWRG3C']

# %% [markdown]
# Credits: the provided codes in Exercise 3 are modified from
# https://arxiv.org/pdf/2301.11009.pdf
